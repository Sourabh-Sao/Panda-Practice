# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('ecommerce_clean.csv')

# %% [markdown]
# ### 1. Show only the rows where the customer is from the "Madhya Pradesh" state.

# %%
# This is boolean indexing
df[df.state=='Madhya Pradesh'] 

#? or 
# This is label based selection 
df.loc[df['state']=='Madhya Pradesh']

#?
df.query("state == 'Madhya Pradesh'")

#?
df[df.state.isin(['Madhya Pradesh'])]
# Out:
#      Unnamed: 0  index   order_id  order_date delivered_date customer_id  \
# 0             0      0  ORD100722  2020-01-01     2020-01-04   CUST10257
# 3             3      3  ORD100031  2020-01-19     2020-01-23   CUST10152
# 15           15     15  ORD100284  2020-02-08     2020-02-15   CUST10061
# 19           19     19  ORD100602  2020-02-12     2020-02-13   CUST10256
# 49           49     49  ORD100725  2020-03-26            NaN   CUST10279
# ..          ...    ...        ...         ...            ...         ...
# 945         945    952  ORD100828  2024-06-08     2024-06-11   CUST10115
# 953         953    960  ORD100678  2024-06-23     2024-06-28   CUST10017
# 966         966    973  ORD100426  2024-07-12     2024-07-15   CUST10274
# 979         979    986  ORD100361  2024-08-13            NaN   CUST10107
# 995         995   1003  ORD100626  2024-09-22            NaN   CUST10266
#
#     customer_name  customer_age customer_gender customer_segment  ...  \
# ...
